# %% [markdown]
# WEATHER DATASET

# %% [markdown]
# Here,the weather dataset is a time-series dataset with per-hour information about the weather conditions at a particular location.
# It records Temperature,Dew point Temperature,Relative Humidity,Wind Speed , Visibility,Pressure and conditions.

# %% [markdown]
# Here,I'm using csv file for dataset.I'm going to analyse this dataset using the Pandas dataframe.

# %%
import pandas as Pd

# %%
data=Pd.read_csv("weather_detailed_dataset.csv")

# %%
data
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0    2024-01-01 23:53              7.2                 0.4
# 1    2024-01-02 09:23             -3.7                -8.1
# 2    2024-01-03 21:19             22.5                12.6
# 3    2024-01-04 19:09             31.5                28.6
# 4    2024-01-05 19:53             -1.6                -3.6
# ..                ...              ...                 ...
# 360  2024-12-26 03:58             -9.8               -11.0
# 361  2024-12-27 23:26              5.3                 1.0
# 362  2024-12-28 23:02             16.2                10.5
# 363  2024-12-29 11:01             -5.4               -14.5
# 364  2024-12-30 05:38             -6.8               -13.3
#
#      Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# 0                       50               28.0             45.6
# 1                       60                9.5             35.4
# 2                       25                4.9             30.0
# ...

# %% [markdown]
# #Analyze the data

# %%
data.head()
# Out:
#           Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0  2024-01-01 23:53              7.2                 0.4
# 1  2024-01-02 09:23             -3.7                -8.1
# 2  2024-01-03 21:19             22.5                12.6
# 3  2024-01-04 19:09             31.5                28.6
# 4  2024-01-05 19:53             -1.6                -3.6
#
#    Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  Pressure (kPa)  \
# 0                     50               28.0             45.6          102.94
# 1                     60                9.5             35.4           97.91
# 2                     25                4.9             30.0          102.84
# 3                     71               40.4             29.0          103.83
# 4                     64               25.9             49.4          100.63
#
#    Weather
# 0  Drizzle
# 1     Rain
# 2   Cloudy
# 3    Clear
# 4      Fog

# %%
data.shape
# Out:
# (365, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=365, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temperature (C)', 'Dew Point Temp (C)',
#        'Relative Humidity (%)', 'Wind Speed (km/h)', 'Visibility (km)',
#        'Pressure (kPa)', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time                 object
# Temperature (C)          float64
# Dew Point Temp (C)       float64
# Relative Humidity (%)      int64
# Wind Speed (km/h)        float64
# Visibility (km)          float64
# Pressure (kPa)           float64
# Weather                   object
# dtype: object

# %%
data.Weather.unique()
# Out:
# array(['Drizzle', 'Rain', 'Cloudy', 'Clear', 'Fog', 'Snow', 'Storm'],
#       dtype=object)

# %%
data.nunique()
# Out:
# Date/Time                365
# Temperature (C)          252
# Dew Point Temp (C)       247
# Relative Humidity (%)     79
# Wind Speed (km/h)        270
# Visibility (km)          259
# Pressure (kPa)           306
# Weather                    7
# dtype: int64

# %%
data.count()
# Out:
# Date/Time                365
# Temperature (C)          365
# Dew Point Temp (C)       365
# Relative Humidity (%)    365
# Wind Speed (km/h)        365
# Visibility (km)          365
# Pressure (kPa)           365
# Weather                  365
# dtype: int64

# %%
data.Weather.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Drizzle
# 1         Rain
# 2       Cloudy
# 3        Clear
# 4          Fog
#         ...
# 360      Storm
# 361    Drizzle
# 362      Clear
# 363    Drizzle
# 364    Drizzle
# Name: Weather, Length: 365, dtype: object>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date/Time              365 non-null    object
#  1   Temperature (C)        365 non-null    float64
#  2   Dew Point Temp (C)     365 non-null    float64
#  3   Relative Humidity (%)  365 non-null    int64
#  4   Wind Speed (km/h)      365 non-null    float64
#  5   Visibility (km)        365 non-null    float64
#  6   Pressure (kPa)         365 non-null    float64
#  7   Weather                365 non-null    object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 22.9+ KB

# %%
data.notnull().sum()
# Out:
# Date/Time                365
# Temperature (C)          365
# Dew Point Temp (C)       365
# Relative Humidity (%)    365
# Wind Speed (km/h)        365
# Visibility (km)          365
# Pressure (kPa)           365
# Weather                  365
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date/Time                0
# Temperature (C)          0
# Dew Point Temp (C)       0
# Relative Humidity (%)    0
# Wind Speed (km/h)        0
# Visibility (km)          0
# Pressure (kPa)           0
# Weather                  0
# dtype: int64

# %% [markdown]
# 1. Find all the unique 'Wind Speed' values in the data.

# %%
data.Weather.value_counts()
# Out:
# Weather
# Drizzle    65
# Snow       59
# Clear      53
# Storm      53
# Cloudy     50
# Fog        43
# Rain       42
# Name: count, dtype: int64

# %% [markdown]
# 2. Find the number of times when the 'Weather is exactly Clear'.

# %%
#Method 1
#value_counts()  (output--> clear : 63)
data.Weather.value_counts()
# Out:
# Weather
# Drizzle    65
# Snow       59
# Clear      53
# Storm      53
# Cloudy     50
# Fog        43
# Rain       42
# Name: count, dtype: int64

# %%
#Method 2
#Filtering
data.Weather=='Clear'
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 360    False
# 361    False
# 362     True
# 363    False
# 364    False
# Name: Weather, Length: 365, dtype: bool

# %%
#Filtering
data[data.Weather=='Clear']
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 3    2024-01-04 19:09             31.5                28.6
# 11   2024-01-12 06:04             -7.1               -16.6
# 12   2024-01-13 09:08             12.9                 5.1
# 19   2024-01-20 21:59             -4.3                -7.8
# 30   2024-01-31 09:30             30.0                26.1
# 40   2024-02-10 21:41              8.9                 4.2
# 48   2024-02-18 19:13             20.2                14.6
# 62   2024-03-03 18:26             22.1                19.7
# 67   2024-03-08 17:01             23.7                20.4
# 75   2024-03-16 10:22             22.2                13.6
# 85   2024-03-26 16:18             16.8                 7.4
# 103  2024-04-13 21:16            -10.0               -17.2
# 106  2024-04-16 03:22             10.7                 6.1
# 114  2024-04-24 10:20              7.7                 0.4
# 115  2024-04-25 00:27             12.0                 9.7
# ...

# %%
#Method 3
#Group by
data.groupby('Weather').get_group('Clear')
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 3    2024-01-04 19:09             31.5                28.6
# 11   2024-01-12 06:04             -7.1               -16.6
# 12   2024-01-13 09:08             12.9                 5.1
# 19   2024-01-20 21:59             -4.3                -7.8
# 30   2024-01-31 09:30             30.0                26.1
# 40   2024-02-10 21:41              8.9                 4.2
# 48   2024-02-18 19:13             20.2                14.6
# 62   2024-03-03 18:26             22.1                19.7
# 67   2024-03-08 17:01             23.7                20.4
# 75   2024-03-16 10:22             22.2                13.6
# 85   2024-03-26 16:18             16.8                 7.4
# 103  2024-04-13 21:16            -10.0               -17.2
# 106  2024-04-16 03:22             10.7                 6.1
# 114  2024-04-24 10:20              7.7                 0.4
# 115  2024-04-25 00:27             12.0                 9.7
# ...

# %% [markdown]
#  3. Find the number of times when the 'Wind Speed was exactly 28 km/h'.

# %%
data.head(2)
# Out:
#           Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0  2024-01-01 23:53              7.2                 0.4
# 1  2024-01-02 09:23             -3.7                -8.1
#
#    Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  Pressure (kPa)  \
# 0                     50               28.0             45.6          102.94
# 1                     60                9.5             35.4           97.91
#
#    Weather
# 0  Drizzle
# 1     Rain

# %%
data[data['Wind Speed (km/h)']==28]
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0    2024-01-01 23:53              7.2                 0.4
# 20   2024-01-21 12:21             12.8                 5.4
# 93   2024-04-03 18:48             -3.0               -10.4
# 249  2024-09-06 01:32             16.1                14.8
#
#      Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# 0                       50               28.0             45.6
# 20                      80               28.0             49.7
# 93                      29               28.0              7.3
# 249                     25               28.0             35.4
#
#      Pressure (kPa)  Weather
# 0            102.94  Drizzle
# 20            99.66  Drizzle
# 93            97.00    Storm
# 249           96.25    Clear

# %% [markdown]
# 4. Find out all the Null Values in the data.

# %%
data.isnull()
# Out:
#      Date/Time  Temperature (C)  Dew Point Temp (C)  Relative Humidity (%)  \
# 0        False            False               False                  False
# 1        False            False               False                  False
# 2        False            False               False                  False
# 3        False            False               False                  False
# 4        False            False               False                  False
# ..         ...              ...                 ...                    ...
# 360      False            False               False                  False
# 361      False            False               False                  False
# 362      False            False               False                  False
# 363      False            False               False                  False
# 364      False            False               False                  False
#
#      Wind Speed (km/h)  Visibility (km)  Pressure (kPa)  Weather
# ...

# %%
data.isnull().sum()
# Out:
# Date/Time                0
# Temperature (C)          0
# Dew Point Temp (C)       0
# Relative Humidity (%)    0
# Wind Speed (km/h)        0
# Visibility (km)          0
# Pressure (kPa)           0
# Weather                  0
# dtype: int64

# %% [markdown]
# 5. Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
data.rename(columns={'Weather':'Weather Condition'})
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0    2024-01-01 23:53              7.2                 0.4
# 1    2024-01-02 09:23             -3.7                -8.1
# 2    2024-01-03 21:19             22.5                12.6
# 3    2024-01-04 19:09             31.5                28.6
# 4    2024-01-05 19:53             -1.6                -3.6
# ..                ...              ...                 ...
# 360  2024-12-26 03:58             -9.8               -11.0
# 361  2024-12-27 23:26              5.3                 1.0
# 362  2024-12-28 23:02             16.2                10.5
# 363  2024-12-29 11:01             -5.4               -14.5
# 364  2024-12-30 05:38             -6.8               -13.3
#
#      Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# 0                       50               28.0             45.6
# 1                       60                9.5             35.4
# 2                       25                4.9             30.0
# ...

# %% [markdown]
# Here , in original dataframe the  column name Weather is not changed Permanently ,so include "inplace=True" in the code

# %%
data
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0    2024-01-01 23:53              7.2                 0.4
# 1    2024-01-02 09:23             -3.7                -8.1
# 2    2024-01-03 21:19             22.5                12.6
# 3    2024-01-04 19:09             31.5                28.6
# 4    2024-01-05 19:53             -1.6                -3.6
# ..                ...              ...                 ...
# 360  2024-12-26 03:58             -9.8               -11.0
# 361  2024-12-27 23:26              5.3                 1.0
# 362  2024-12-28 23:02             16.2                10.5
# 363  2024-12-29 11:01             -5.4               -14.5
# 364  2024-12-30 05:38             -6.8               -13.3
#
#      Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# 0                       50               28.0             45.6
# 1                       60                9.5             35.4
# 2                       25                4.9             30.0
# ...

# %%
data.rename(columns={'Weather':'Weather Condition'},inplace=True)

# %%
data
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0    2024-01-01 23:53              7.2                 0.4
# 1    2024-01-02 09:23             -3.7                -8.1
# 2    2024-01-03 21:19             22.5                12.6
# 3    2024-01-04 19:09             31.5                28.6
# 4    2024-01-05 19:53             -1.6                -3.6
# ..                ...              ...                 ...
# 360  2024-12-26 03:58             -9.8               -11.0
# 361  2024-12-27 23:26              5.3                 1.0
# 362  2024-12-28 23:02             16.2                10.5
# 363  2024-12-29 11:01             -5.4               -14.5
# 364  2024-12-30 05:38             -6.8               -13.3
#
#      Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# 0                       50               28.0             45.6
# 1                       60                9.5             35.4
# 2                       25                4.9             30.0
# ...

# %% [markdown]
# 6.What is the mean 'Visibility' ?

# %%
data.head(2)
# Out:
#           Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0  2024-01-01 23:53              7.2                 0.4
# 1  2024-01-02 09:23             -3.7                -8.1
#
#    Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  Pressure (kPa)  \
# 0                     50               28.0             45.6          102.94
# 1                     60                9.5             35.4           97.91
#
#   Weather Condition
# 0           Drizzle
# 1              Rain

# %%
data['Visibility (km)'].mean()
# Out:
# 26.17917808219178

# %% [markdown]
# 7. What is the Standard Deviation of 'Pressure' in this data?

# %%
data['Pressure (kPa)'].std()
# Out:
# 2.9123305491922684

# %% [markdown]
# 8. What is the Variance of 'Relative Humidity' in this data ?

# %%
data.head(2)
# Out:
#           Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0  2024-01-01 23:53              7.2                 0.4
# 1  2024-01-02 09:23             -3.7                -8.1
#
#    Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  Pressure (kPa)  \
# 0                     50               28.0             45.6          102.94
# 1                     60                9.5             35.4           97.91
#
#   Weather Condition
# 0           Drizzle
# 1              Rain

# %%
data['Relative Humidity (%)'].var()
# Out:
# 547.7813788950776

# %% [markdown]
# 9. Find all instances when 'Snow' was recorded.

# %%
#Method 1 
#value_counts()
data['Weather Condition'].value_counts()
# Out:
# Weather Condition
# Drizzle    65
# Snow       59
# Clear      53
# Storm      53
# Cloudy     50
# Fog        43
# Rain       42
# Name: count, dtype: int64

# %%
#Method2 
#Filtering
data[data['Weather Condition']=='Snow']
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 7    2024-01-08 12:23             -8.3               -16.4
# 10   2024-01-11 19:00              1.8                -2.5
# 14   2024-01-15 14:53             13.0                 4.7
# 22   2024-01-23 22:04             30.1                21.3
# 23   2024-01-24 13:44             17.8                 9.1
# 26   2024-01-27 21:27             -9.3               -19.1
# 31   2024-02-01 23:12             16.3                 9.7
# 32   2024-02-02 10:24             34.4                30.7
# 38   2024-02-08 12:57              3.8                -2.5
# 39   2024-02-09 17:57             30.6                23.8
# 42   2024-02-12 07:29             22.7                20.0
# 44   2024-02-14 12:26             12.3                 2.4
# 45   2024-02-15 07:29              3.6                -5.8
# 47   2024-02-17 09:11             14.2                 7.9
# 58   2024-02-28 12:44             23.1                20.0
# ...

# %%
#Method 3
#str Contains
data[data['Weather Condition'].str.contains('Snow')].tail(50)
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 39   2024-02-09 17:57             30.6                23.8
# 42   2024-02-12 07:29             22.7                20.0
# 44   2024-02-14 12:26             12.3                 2.4
# 45   2024-02-15 07:29              3.6                -5.8
# 47   2024-02-17 09:11             14.2                 7.9
# 58   2024-02-28 12:44             23.1                20.0
# 71   2024-03-12 13:29             23.8                15.4
# 72   2024-03-13 04:03             -0.9                -4.2
# 74   2024-03-15 07:23             35.0                29.3
# 76   2024-03-17 19:31             30.9                23.8
# 90   2024-03-31 16:32             19.7                11.0
# 117  2024-04-27 13:58             -8.6               -11.7
# 126  2024-05-06 09:59             33.6                28.0
# 129  2024-05-09 04:18             34.8                26.1
# 134  2024-05-14 22:31             29.0                20.6
# ...

# %% [markdown]
# 10. Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
data.head(2)
# Out:
#           Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0  2024-01-01 23:53              7.2                 0.4
# 1  2024-01-02 09:23             -3.7                -8.1
#
#    Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  Pressure (kPa)  \
# 0                     50               28.0             45.6          102.94
# 1                     60                9.5             35.4           97.91
#
#   Weather Condition
# 0           Drizzle
# 1              Rain

# %%
data[(data['Wind Speed (km/h)']>24) & (data['Visibility (km)']==25)]
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 196  2024-07-15 19:17             31.2                25.7
#
#      Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# 196                     90               34.8             25.0
#
#      Pressure (kPa) Weather Condition
# 196          103.71               Fog

# %%
data
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0    2024-01-01 23:53              7.2                 0.4
# 1    2024-01-02 09:23             -3.7                -8.1
# 2    2024-01-03 21:19             22.5                12.6
# 3    2024-01-04 19:09             31.5                28.6
# 4    2024-01-05 19:53             -1.6                -3.6
# ..                ...              ...                 ...
# 360  2024-12-26 03:58             -9.8               -11.0
# 361  2024-12-27 23:26              5.3                 1.0
# 362  2024-12-28 23:02             16.2                10.5
# 363  2024-12-29 11:01             -5.4               -14.5
# 364  2024-12-30 05:38             -6.8               -13.3
#
#      Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# 0                       50               28.0             45.6
# 1                       60                9.5             35.4
# 2                       25                4.9             30.0
# ...

# %% [markdown]
# 11. What is the Mean value of each column against each 'Weather Condition ?

# %%
import pandas as pd

data = pd.read_csv("weather_detailed_dataset.csv")
numeric_columns = data.select_dtypes(include=['number'])
mean_values = data.groupby("Weather")[numeric_columns.columns].mean()

print(mean_values)
# Out:
#          Temperature (C)  Dew Point Temp (C)  Relative Humidity (%)  \
# Weather
# Clear          15.669811           10.233962              56.698113
# Cloudy         15.288000            9.986000              58.980000
# Drizzle        12.163077            6.670769              62.676923
# Fog            14.360465            8.909302              56.976744
# Rain           12.016667            6.959524              59.119048
# Snow           15.298305            9.523729              58.033898
# Storm           9.541509            4.032075              51.622642
#
#          Wind Speed (km/h)  Visibility (km)  Pressure (kPa)
# Weather
# Clear            25.796226        29.788679       99.620943
# Cloudy           26.010000        23.172000      100.411000
# Drizzle          25.473846        25.546154      100.124615
# Fog              26.744186        26.162791       99.947907
# Rain             20.173810        24.738095       99.368810
# ...

# %% [markdown]
# 12. What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
data.groupby('Weather').min()
# Out:
#                 Date/Time  Temperature (C)  Dew Point Temp (C)  \
# Weather
# Clear    2024-01-04 19:09            -10.0               -17.2
# Cloudy   2024-01-03 21:19             -9.9               -16.2
# Drizzle  2024-01-01 23:53             -8.9               -17.5
# Fog      2024-01-05 19:53             -4.9               -10.7
# Rain     2024-01-02 09:23             -8.3               -17.3
# Snow     2024-01-08 12:23             -9.3               -19.1
# Storm    2024-01-16 11:42             -9.8               -15.7
#
#          Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# Weather
# Clear                       21                2.6              1.1
# Cloudy                      23                1.1              1.4
# Drizzle                     20                0.9              2.2
# Fog                         21                0.6              3.5
# Rain                        20                0.3              1.3
# ...

# %%
data.groupby('Weather').max()
# Out:
#                 Date/Time  Temperature (C)  Dew Point Temp (C)  \
# Weather
# Clear    2024-12-28 23:02             34.0                30.7
# Cloudy   2024-12-19 10:32             33.6                32.2
# Drizzle  2024-12-30 05:38             34.6                32.0
# Fog      2024-12-24 02:03             33.4                27.7
# Rain     2024-12-25 04:42             34.3                32.0
# Snow     2024-12-14 17:08             35.0                30.7
# Storm    2024-12-26 03:58             34.9                32.5
#
#          Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# Weather
# Clear                       95               50.0             49.7
# Cloudy                     100               49.3             48.1
# Drizzle                     99               50.0             49.7
# Fog                         97               49.2             49.4
# Rain                       100               48.8             49.7
# ...

# %% [markdown]
# 13.  Show all the Records where Weather Condition is Fog.

# %%
data[data['Weather']=='Fog']
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 4    2024-01-05 19:53             -1.6                -3.6
# 6    2024-01-07 14:16              1.6                -0.0
# 9    2024-01-10 22:27             26.8                21.6
# 29   2024-01-30 22:45             26.7                21.0
# 41   2024-02-11 15:37             29.8                21.3
# 51   2024-02-21 22:03             25.9                20.9
# 52   2024-02-22 18:27             21.4                11.6
# 61   2024-03-02 02:29              7.1                -1.6
# 64   2024-03-05 07:28             -1.5                -3.7
# 78   2024-03-19 03:44             -4.9                -7.0
# 87   2024-03-28 13:16             24.5                19.6
# 104  2024-04-14 17:44             15.9                12.4
# 113  2024-04-23 12:46             21.0                12.2
# 137  2024-05-17 11:17              3.7                -4.8
# 154  2024-06-03 02:53             15.7                 7.3
# ...

# %% [markdown]
# 14. Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
data[(data['Weather']=='Clear') | (data['Visibility (km)']>40)]
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0    2024-01-01 23:53              7.2                 0.4
# 3    2024-01-04 19:09             31.5                28.6
# 4    2024-01-05 19:53             -1.6                -3.6
# 11   2024-01-12 06:04             -7.1               -16.6
# 12   2024-01-13 09:08             12.9                 5.1
# ..                ...              ...                 ...
# 351  2024-12-17 09:47             32.0                29.2
# 352  2024-12-18 08:21             -1.0               -10.7
# 360  2024-12-26 03:58             -9.8               -11.0
# 361  2024-12-27 23:26              5.3                 1.0
# 362  2024-12-28 23:02             16.2                10.5
#
#      Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# 0                       50               28.0             45.6
# 3                       71               40.4             29.0
# 4                       64               25.9             49.4
# ...

# %% [markdown]
# 15. Find all instances when : A. 'Weather is Clear' and 'Relative Humidity is greater than 25' or B. 'Visibility is above 40'

# %%
data.head(2)
# Out:
#           Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0  2024-01-01 23:53              7.2                 0.4
# 1  2024-01-02 09:23             -3.7                -8.1
#
#    Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  Pressure (kPa)  \
# 0                     50               28.0             45.6          102.94
# 1                     60                9.5             35.4           97.91
#
#    Weather
# 0  Drizzle
# 1     Rain

# %%
data[(data['Weather']=='Clear') & (data['Relative Humidity (%)']>25) | (data['Visibility (km)']>40)]
# Out:
#             Date/Time  Temperature (C)  Dew Point Temp (C)  \
# 0    2024-01-01 23:53              7.2                 0.4
# 3    2024-01-04 19:09             31.5                28.6
# 4    2024-01-05 19:53             -1.6                -3.6
# 12   2024-01-13 09:08             12.9                 5.1
# 16   2024-01-17 08:27             29.8                26.3
# ..                ...              ...                 ...
# 351  2024-12-17 09:47             32.0                29.2
# 352  2024-12-18 08:21             -1.0               -10.7
# 360  2024-12-26 03:58             -9.8               -11.0
# 361  2024-12-27 23:26              5.3                 1.0
# 362  2024-12-28 23:02             16.2                10.5
#
#      Relative Humidity (%)  Wind Speed (km/h)  Visibility (km)  \
# 0                       50               28.0             45.6
# 3                       71               40.4             29.0
# 4                       64               25.9             49.4
# ...
